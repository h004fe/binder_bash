# %%
ls /bin /usr/bin
# Out:
# /bin:
# '['                               lspgpot
#  aclocal                          lto-dump-11
#  aclocal-1.16                     lzcat
#  addpart                          lzcmp
#  addr2line                        lzdiff
#  animate                          lzegrep
#  animate-im6                      lzfgrep
#  animate-im6.q16                  lzgrep
#  apt                              lzless
#  apt-cache                        lzma
#  apt-cdrom                        lzmainfo
#  apt-config                       lzmore
#  apt-get                          m4
#  apt-key                          make
#  apt-mark                         makeconv
#  ar                               make-first-existing-target
#  arch                             man
#  as                               mawk
#  autoconf                         mcookie
#  autoheader                       md5sum
#  autom4te                         md5sum.textutils
#  automake                         mesg
# ...
