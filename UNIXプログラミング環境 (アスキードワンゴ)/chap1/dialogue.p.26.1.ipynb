# %%
# Prerequisites
./pre_dialogue.p.22.2 && cd "/home/jovyan/UNIXプログラミング環境 (アスキードワンゴ)/tmp"
# Out:
# -------- [in the bash environment] --------
# $ ed
# a
# To be or not to be
# .
# w junk
# 19
# q
# $ ed
# a
# This is the question.
# .
# w temp
# 2
# q
# -------------------------------------------

# %%
pr junk temp
# Out:
# 2024-06-23 05:49                       junk                       Page 1
#
#
# To be or not to be
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2024-06-23 05:49                       temp                       Page 1
#
#
# This is the question.
